# %%
import numpy as np
import importlib

# %%
import halo_and_cluster_MF as hcmf

# %%
hcmf.hello_world()
# Out:
# Hello, world! version 1

# %%
hcmf.hello_world()
# Out:
# Hello, world! version 1

# %%
hcmf.hello_world()
# Out:
# Hello, world! version 1

# %%
importlib.reload(hcmf)
# Out:
# <module 'halo_and_cluster_MF' from '\\\\dapdc5\\ED282972\\My Documents\\Stage\\Content\\caracterisation selection effects\\halo_and_cluster_MF.py'>

# %%
hcmf.hello_world()
# Out:
# Hello, world! version 2

# %%
importlib.reload(hcmf)
# Out:
# <module 'halo_and_cluster_MF' from '\\\\dapdc5\\ED282972\\My Documents\\Stage\\Content\\caracterisation selection effects\\halo_and_cluster_MF.py'>

# %%
hcmf.hello_world()
# Out:
# Hello, world! version 3
